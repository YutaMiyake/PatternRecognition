# %%
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nums1 = np.loadtxt("Faces/correctImages.txt")
nums2 = np.loadtxt("Faces/correctImages_90.txt")
nums3 = np.loadtxt("Faces/correctImages_95.txt")

plot(nums1/1196, '-or', label="80%")
plot(nums2/1196, '-*g', label="90%")
plot(nums3/1196,'-xb', label="95%")

plt.legend(bbox_to_anchor=(1, 0.3), loc=0, borderaxespad=0.5)

title("Comparative CMC graph")
xlabel("N face gallery")
ylabel("Performance")
